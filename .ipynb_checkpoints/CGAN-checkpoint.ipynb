# %%
import os
import pandas as pd
from PIL import Image
import torch.nn as nn
import torch
from torch.autograd import Variable
import numpy as np
import pandas as pd
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from torch import autograd
from torch.autograd import Variable
from torchvision.utils import make_grid
import matplotlib.pyplot as plt

from torch import optim as optim
#from torch.nn.functional import one_hot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-81-19b1427f44ae> in <module>
#      16
#      17 from torch import optim as optim
# ---> 18 from torch.nn.functional import one_hot
#
# ImportError: cannot import name 'one_hot' from 'torch.nn.functional' (/opt/anaconda3/envs/rnvp/lib/python3.7/site-packages/torch/nn/functional.py)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
training_parameters = {
    "n_epochs": 30,
    "batch_size": 100,
}

# %%
pictures_df = pd.read_csv('/Users/test/Desktop/Master_Thesis_Flow/real-nvp/data/GPR_Data/B200/labels_complete_dataset_607.csv')

# %%
filename = pictures_df['filename'].values

className = pictures_df['class'].values

file_class_mapping_dict = {}
for i in range(len(filename)):
    file_class_mapping_dict[filename[i]] = className[i]

# %%
len(file_class_mapping_dict)
# Out:
# 1275

# %%
list(pictures_df)
# Out:
# ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']

# %%
DataPath = '/Users/test/Desktop/Master_Thesis_Flow/real-nvp/data/GPR_Data/B200/B200_Pictures_GR'
    
dirs = os.listdir(DataPath)


labels = []

images = []

imageName = []
final_image_list = []

def crop():
    for item in dirs:
        try:
            fullpath = os.path.join(DataPath,item)         #corrected
            if os.path.isfile(fullpath):
                im = Image.open(fullpath).convert('L')
                f, e = os.path.splitext(fullpath)
                imCrop = im.crop((0, 0, 128, 128)) #corrected                
                labels.append(file_class_mapping_dict[item])
                images.append(imCrop)
                imageName.append(item)
                temp_tuple = (imCrop , file_class_mapping_dict[item] )
                print(temp_tuple)
                final_image_list.append(temp_tuple)
                x += 1
        except:
            k =1
            
            
crop()
# Out:
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD141B080>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD141BB38>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD173FF60>, 'hyperbel')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4A58>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4CF8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4DA0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4C50>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4898>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4518>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4160>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C46D8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4630>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C45F8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4FD0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07784E0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07788D0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778F98>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4F60>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07784A8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07786D8>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778E48>, 'schichtmarker')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778518>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778470>, 'hyperbel')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778FD0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778E80>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778EF0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CB38>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C630>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C780>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778940>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C4A8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C898>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CA58>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C550>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CCC0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CBA8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CC88>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C978>, 'schichtmarker')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C748>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CE48>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CC18>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CDA0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15245F8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524630>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524B38>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524F98>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524E10>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15241D0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524B00>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524978>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524E80>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524BA8>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15247F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524EF0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524EB8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524048>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524DD8>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15246A0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15247B8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524940>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524278>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524080>, 'schichtmarker')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524710>, 'schichtmarker')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524D30>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524DA0>, 'schichtmarker')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524898>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15240F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524D68>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524160>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15242B0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524CC0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524F60>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67198>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524E48>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC676D8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67DA0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67B00>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67978>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67518>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC675F8>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67BE0>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67278>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67898>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67EB8>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67438>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67F98>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67A20>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67358>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67CC0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC677B8>, 'hyperbel')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC670B8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67E48>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0390>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0358>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0518>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0588>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0EB8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0F98>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0748>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0710>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0668>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E05F8>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0780>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0A58>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0438>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0F60>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E06D8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E02E8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0400>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0E80>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372DA0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372E10>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372208>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372FD0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372550>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13726A0>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372978>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372588>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372B00>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13725C0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372860>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372EF0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13727B8>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13728D0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372A58>, 'schichtmarker')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13722E8>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD0257F0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372898>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372A90>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13726D8>, 'hyperbel')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372630>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372748>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372B38>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13723C8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13729B0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13724E0>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372DD8>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372470>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372EB8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13720F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372E80>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372908>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13721D0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372400>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372240>, 'aufbauanomalie')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372BE0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372B70>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372278>, 'schichtmarker')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372668>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372780>, 'aufbauanomalie')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372080>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13722B0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372940>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372048>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13729E8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372BA8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372198>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372128>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372160>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372438>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372D68>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372C18>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372710>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372F28>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372CF8>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372390>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372CC0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13727F0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13724A8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372F98>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372828>, 'aufbauanomalie')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372D30>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372AC8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372F60>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07BB0F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14344E0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434358>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434F98>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434400>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434630>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14347F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434D30>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434048>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14340B8>, 'aufbauanomalie')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434780>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434EB8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434668>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434CF8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14341D0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434438>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434C50>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434A58>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434748>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434E80>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14342E8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434160>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434B70>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14346D8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434978>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434320>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434940>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434FD0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434710>, 'aufbauanomalie')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14346A0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434390>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434860>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434C18>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434F60>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372518>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434080>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434518>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434198>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14340F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434908>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434EF0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434208>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14344A8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434B00>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14345C0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434240>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434550>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14349E8>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14347B8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434A90>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434A20>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434278>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434D68>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14345F8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434E48>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14348D0>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434AC8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434DA0>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434B38>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434BA8>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACA639C50>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD052EAC8>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BF28>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BBE0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B0F0>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B128>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B080>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BD68>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BDD8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B198>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B160>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BFD0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BEF0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B400>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B0B8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B240>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BE80>, 'hyperbel')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BCF8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BC50>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1214470>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1214518>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1214240>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12143C8>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12145F8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BE48>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212E10>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212B38>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12125F8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212A90>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12126D8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212438>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212F28>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212E80>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212BE0>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212FD0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212C88>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212B70>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212F60>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212D30>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212780>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212EB8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212400>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212CC0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212358>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12129E8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212AC8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212748>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFA58>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFA20>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF438>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF518>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFD68>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFC50>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFF98>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF940>, 'schichtmarker')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF320>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF8D0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF4A8>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFF28>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFEF0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFBA8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF7B8>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFCC0>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF860>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF2B0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFB00>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF9B0>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFCF8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF898>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF400>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF208>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFDA0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF710>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF6D8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF278>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF630>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF5C0>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF908>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFD30>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF3C8>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF080>, 'aufbauanomalie')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF198>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF0B8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF470>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFB38>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF7F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFBE0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFC88>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF9E8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF978>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF668>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF588>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF1D0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFB70>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF5F8>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFC18>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFA90>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFAC8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF6A0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF748>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF550>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF780>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF2E8>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF4E0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF390>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFE80>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF240>, 'aufbauanomalie')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF358>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF048>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD8FAFD0>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF160>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF0F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF128>, 'aufbauanomalie')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD8FA160>, 'aufbauanomalie')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD91BB00>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8BE0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8940>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8550>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E89E8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434CC0>, 'hyperbel')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E85F8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8DD8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8EB8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E87F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E80B8>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8160>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E84A8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8208>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E82B0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E86A0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E80F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8630>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8358>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8588>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8B38>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8A90>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8F28>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8908>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8B70>, 'aufbauanomalie')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8748>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8C18>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8B00>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8898>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8390>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8128>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8518>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8A58>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8710>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E87B8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8F60>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E88D0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8240>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8978>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8A20>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8048>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E89B0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8198>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E83C8>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8320>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E82E8>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8E48>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8AC8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8860>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8438>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8C50>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8EF0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8400>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E84E0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8DA0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8BA8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8780>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8E10>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8278>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E86D8>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8828>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8D68>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E85C0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD550>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD1D0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FDFD0>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD080>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD4A8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD240>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD0F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD2E8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FDC88>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD748>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD278>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FDF98>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD320>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784908>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784048>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784668>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784550>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784AC8>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07849E8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784B00>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784828>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784940>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07844E0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784A20>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243828>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12436A0>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243A90>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243550>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243048>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12435C0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243B00>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243278>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243780>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243B70>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243160>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243898>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1258860>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1258320>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1258CC0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1258C50>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1258CF8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263240>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263400>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12632B0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263978>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263438>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263F28>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263E48>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263208>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263CC0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12637F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12630B8>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263F60>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263B70>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1278128>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1278A58>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12786D8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263160>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12787F0>, 'hyperbel')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1278828>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12787B8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12786A0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1278E80>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12784A8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1278B70>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561780>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561518>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561CF8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15617B8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561AC8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561470>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15614E0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561828>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561EB8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561EF0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07534A8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753550>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07536D8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753A90>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753940>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753B00>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753AC8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753BA8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753B38>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753E10>, 'aufbauanomalie')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753B70>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753F28>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753E80>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E81D0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753748>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753FD0>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753EF0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753F98>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753358>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD01E2E8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753A58>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753F60>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD01E2B0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753BE0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD01E240>, 'hyperbel')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD120F898>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD120F940>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD120F390>, 'hyperbel')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD120FCC0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD120F048>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CABA8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CACF8>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA860>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CADA0>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAE48>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA518>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CACC0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA7B8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA550>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA7F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAEB8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAD68>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA358>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAF98>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA400>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAA58>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA2E8>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAE10>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAF60>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAB38>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA828>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAEF0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA780>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA390>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA4A8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED4E0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED6A0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED2B0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED550>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED828>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED470>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753A20>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED128>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED518>, 'schichtmarker')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED5F8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED940>, 'schichtmarker')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED7F0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED898>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06EDBE0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06EDB38>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED358>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED400>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED8D0>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06EDDD8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED9E8>, 'schichtabloesung lang')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06EDD30>, 'mehrfachschichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED160>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED748>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED208>, 'deckschichtschaden')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED4A8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED0B8>, 'schichtabloesung')
# (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06EDC88>, 'schichtabloesung')

# %%
len(labels)

labels[0]
# Out:
# 'schichtabloesung'

# %%
UniqueLabels = np.unique(labels)

labelsDict = {}

for i, label in enumerate(UniqueLabels):
    labelsDict[label] = i
    
file_label_map_dict = {}
for i in range(len(images)): 
#     print(labels[i])
    file_label_map_dict[filename[i]] = labelsDict[labels[i]]

# %%
final_image_list
# Out:
# [(<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD141B080>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD141BB38>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD173FF60>, 'hyperbel'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4A58>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4CF8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4DA0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4C50>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4898>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4518>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4160>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C46D8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4630>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C45F8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4FD0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07784E0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07788D0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778F98>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD04C4F60>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07784A8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07786D8>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778E48>,
#   'schichtmarker'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778518>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778470>, 'hyperbel'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778FD0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778E80>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778EF0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CB38>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C630>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C780>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0778940>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C4A8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C898>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CA58>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C550>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CCC0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CBA8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CC88>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C978>,
#   'schichtmarker'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5C748>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CE48>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CC18>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC5CDA0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15245F8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524630>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524B38>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524F98>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524E10>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15241D0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524B00>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524978>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524E80>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524BA8>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15247F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524EF0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524EB8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524048>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524DD8>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15246A0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15247B8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524940>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524278>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524080>,
#   'schichtmarker'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524710>,
#   'schichtmarker'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524D30>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524DA0>,
#   'schichtmarker'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524898>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15240F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524D68>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524160>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15242B0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524CC0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524F60>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67198>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1524E48>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC676D8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67DA0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67B00>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67978>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67518>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC675F8>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67BE0>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67278>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67898>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67EB8>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67438>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67F98>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67A20>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67358>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67CC0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC677B8>, 'hyperbel'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC670B8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACDC67E48>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0390>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0358>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0518>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0588>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0EB8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0F98>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0748>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0710>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0668>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E05F8>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0780>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0A58>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0438>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0F60>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E06D8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E02E8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0400>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD10E0E80>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372DA0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372E10>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372208>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372FD0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372550>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13726A0>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372978>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372588>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372B00>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13725C0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372860>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372EF0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13727B8>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13728D0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372A58>,
#   'schichtmarker'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13722E8>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD0257F0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372898>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372A90>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13726D8>, 'hyperbel'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372630>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372748>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372B38>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13723C8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13729B0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13724E0>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372DD8>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372470>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372EB8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13720F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372E80>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372908>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13721D0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372400>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372240>,
#   'aufbauanomalie'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372BE0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372B70>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372278>,
#   'schichtmarker'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372668>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372780>,
#   'aufbauanomalie'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372080>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13722B0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372940>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372048>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13729E8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372BA8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372198>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372128>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372160>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372438>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372D68>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372C18>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372710>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372F28>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372CF8>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372390>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372CC0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13727F0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD13724A8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372F98>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372828>,
#   'aufbauanomalie'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372D30>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372AC8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372F60>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07BB0F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14344E0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434358>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434F98>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434400>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434630>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14347F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434D30>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434048>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14340B8>,
#   'aufbauanomalie'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434780>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434EB8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434668>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434CF8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14341D0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434438>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434C50>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434A58>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434748>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434E80>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14342E8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434160>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434B70>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14346D8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434978>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434320>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434940>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434FD0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434710>,
#   'aufbauanomalie'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14346A0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434390>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434860>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434C18>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434F60>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1372518>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434080>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434518>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434198>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14340F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434908>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434EF0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434208>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14344A8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434B00>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14345C0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434240>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434550>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14349E8>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14347B8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434A90>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434A20>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434278>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434D68>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14345F8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434E48>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14348D0>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434AC8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434DA0>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434B38>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434BA8>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACA639C50>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD052EAC8>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BF28>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BBE0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B0F0>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B128>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B080>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BD68>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BDD8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B198>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B160>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BFD0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BEF0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B400>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B0B8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054B240>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BE80>, 'hyperbel'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BCF8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BC50>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1214470>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1214518>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1214240>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12143C8>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12145F8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD054BE48>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212E10>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212B38>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12125F8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212A90>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12126D8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212438>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212F28>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212E80>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212BE0>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212FD0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212C88>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212B70>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212F60>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212D30>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212780>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212EB8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212400>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212CC0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212358>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12129E8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212AC8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1212748>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFA58>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFA20>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF438>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF518>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFD68>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFC50>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFF98>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF940>,
#   'schichtmarker'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF320>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF8D0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF4A8>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFF28>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFEF0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFBA8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF7B8>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFCC0>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF860>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF2B0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFB00>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF9B0>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFCF8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF898>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF400>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF208>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFDA0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF710>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF6D8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF278>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF630>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF5C0>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF908>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFD30>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF3C8>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF080>,
#   'aufbauanomalie'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF198>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF0B8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF470>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFB38>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF7F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFBE0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFC88>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF9E8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF978>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF668>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF588>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF1D0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFB70>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF5F8>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFC18>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFA90>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFAC8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF6A0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF748>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF550>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF780>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF2E8>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF4E0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF390>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EFE80>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF240>,
#   'aufbauanomalie'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF358>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF048>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD8FAFD0>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF160>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF0F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD14EF128>,
#   'aufbauanomalie'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD8FA160>,
#   'aufbauanomalie'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD91BB00>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8BE0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8940>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8550>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E89E8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1434CC0>, 'hyperbel'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E85F8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8DD8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8EB8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E87F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E80B8>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8160>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E84A8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8208>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E82B0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E86A0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E80F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8630>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8358>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8588>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8B38>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8A90>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8F28>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8908>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8B70>,
#   'aufbauanomalie'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8748>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8C18>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8B00>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8898>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8390>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8128>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8518>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8A58>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8710>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E87B8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8F60>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E88D0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8240>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8978>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8A20>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8048>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E89B0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8198>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E83C8>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8320>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E82E8>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8E48>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8AC8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8860>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8438>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8C50>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8EF0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8400>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E84E0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8DA0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8BA8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8780>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8E10>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8278>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E86D8>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8828>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E8D68>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E85C0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD550>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD1D0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FDFD0>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD080>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD4A8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD240>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD0F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD2E8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FDC88>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD748>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD278>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FDF98>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06FD320>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784908>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784048>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784668>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784550>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784AC8>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07849E8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784B00>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784828>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784940>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07844E0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0784A20>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243828>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12436A0>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243A90>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243550>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243048>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12435C0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243B00>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243278>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243780>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243B70>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243160>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1243898>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1258860>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1258320>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1258CC0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1258C50>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1258CF8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263240>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263400>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12632B0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263978>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263438>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263F28>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263E48>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263208>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263CC0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12637F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12630B8>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263F60>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263B70>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1278128>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1278A58>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12786D8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1263160>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12787F0>, 'hyperbel'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1278828>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12787B8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12786A0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1278E80>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD12784A8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1278B70>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561780>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561518>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561CF8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15617B8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561AC8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561470>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD15614E0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561828>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561EB8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD1561EF0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07534A8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753550>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD07536D8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753A90>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753940>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753B00>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753AC8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753BA8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753B38>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753E10>,
#   'aufbauanomalie'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753B70>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753F28>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753E80>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06E81D0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753748>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753FD0>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753EF0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753F98>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753358>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD01E2E8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753A58>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753F60>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD01E2B0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753BE0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFACD01E240>, 'hyperbel'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD120F898>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD120F940>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD120F390>, 'hyperbel'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD120FCC0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD120F048>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CABA8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CACF8>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA860>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CADA0>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAE48>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA518>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CACC0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA7B8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA550>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA7F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAEB8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAD68>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA358>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAF98>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA400>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAA58>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA2E8>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAE10>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAF60>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAB38>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA828>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CAEF0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA780>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA390>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06CA4A8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED4E0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED6A0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED2B0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED550>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED828>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED470>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD0753A20>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED128>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED518>,
#   'schichtmarker'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED5F8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED940>,
#   'schichtmarker'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED7F0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED898>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06EDBE0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06EDB38>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED358>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED400>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED8D0>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06EDDD8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED9E8>,
#   'schichtabloesung lang'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06EDD30>,
#   'mehrfachschichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED160>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED748>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED208>,
#   'deckschichtschaden'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED4A8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06ED0B8>,
#   'schichtabloesung'),
#  (<PIL.Image.Image image mode=L size=128x128 at 0x7FFAD06EDC88>,
#   'schichtabloesung')]

# %%
len(imageName)
# Out:
# 568

# %%
class GeneratorModel(nn.Module):
    def __init__(self):
        super(GeneratorModel, self).__init__()
        input_dim = 128 + 7
        output_dim = 128
        self.label_embedding = nn.Embedding(7, 7)
        
        self.hidden_layer1 = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.LeakyReLU(0.2)
        )

        self.hidden_layer2 = nn.Sequential(
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2)
        )

        self.hidden_layer3 = nn.Sequential(
            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2)
        )

        self.hidden_layer4 = nn.Sequential(
            nn.Linear(1024, output_dim),
            nn.Tanh()
        )
    
    def forward(self, x, labels):
        c = self.label_embedding(labels)
        x = torch.cat([x,c], 1)
        output = self.hidden_layer1(x)
        output = self.hidden_layer2(output)
        output = self.hidden_layer3(output)
        output = self.hidden_layer4(output)
        return output.to(device)

# %%
class DiscriminatorModel(nn.Module):
    def __init__(self):
        super(DiscriminatorModel, self).__init__()
        input_dim = 128 + 7
        output_dim = 1
        self.label_embedding = nn.Embedding(7, 7)

        self.hidden_layer1 = nn.Sequential(
            nn.Linear(input_dim, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )

        self.hidden_layer2 = nn.Sequential(
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )

        self.hidden_layer3 = nn.Sequential(
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )

        self.hidden_layer4 = nn.Sequential(
            nn.Linear(256, output_dim),
            nn.Sigmoid()
        )

    def forward(self, x, labels):
        c = self.label_embedding(labels)
        x = torch.cat([x, c], 1)
        output = self.hidden_layer1(x)
        output = self.hidden_layer2(output)
        output = self.hidden_layer3(output)
        output = self.hidden_layer4(output)

        return output.to(device)

# %%
discriminator = DiscriminatorModel()
generator = GeneratorModel()
discriminator.to(device)
generator.to(device)
# Out:
# GeneratorModel(
#   (label_embedding): Embedding(7, 7)
#   (hidden_layer1): Sequential(
#     (0): Linear(in_features=135, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#   )
#   (hidden_layer2): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#   )
#   (hidden_layer3): Sequential(
#     (0): Linear(in_features=512, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#   )
#   (hidden_layer4): Sequential(
#     (0): Linear(in_features=1024, out_features=128, bias=True)
#     (1): Tanh()
#   )
# )

# %%
loss = nn.BCELoss()
discriminator_optimizer = optim.Adam(discriminator.parameters(), lr=0.0002)
generator_optimizer = optim.Adam(generator.parameters(), lr=0.0002)

# %%
#Training

n_epochs = training_parameters["n_epochs"]
batch_size = training_parameters["batch_size"]
#batch_size = batch_size.type(torch.LongTensor)
for epoch_idx in range(n_epochs):
    G_loss = []
    D_loss = []
    for batch_idx, data_input in enumerate(final_image_list):
        
        
        noise = torch.randn(batch_size,128).to(device)
        fake_labels = torch.randint(0, 7, (batch_size,)).to(device)
        generated_data = generator(noise, fake_labels.type(torch.LongTensor)) # batch_size X 784

        
        # Discriminator
        true_data = data_input[0] # batch_size X 784
        digit_labels = torch.Tensor(labelsDict[data_input[1]]) # batch_size
        
        true_labels = torch.ones(batch_size).to(device)
        
        discriminator_optimizer.zero_grad()

        discriminator_output_for_true_data = discriminator(true_data, digit_labels).view(batch_size)
        true_discriminator_loss = loss(discriminator_output_for_true_data, true_labels)

        discriminator_output_for_generated_data = discriminator(generated_data.detach(), fake_labels).view(batch_size)
        generator_discriminator_loss = loss(
            discriminator_output_for_generated_data, torch.zeros(batch_size).to(device)
        )
        discriminator_loss = (
            true_discriminator_loss + generator_discriminator_loss
        ) / 2
        
        discriminator_loss.backward()
        discriminator_optimizer.step()

        D_loss.append(discriminator_loss.data.item())
        
        
        # Generator

        generator_optimizer.zero_grad()
        # It's a choice to generate the data again
        generated_data = generator(noise, fake_labels) # batch_size X 784
        discriminator_output_on_generated_data = discriminator(generated_data, fake_labels).view(batch_size)
        generator_loss = loss(discriminator_output_on_generated_data, true_labels)
        generator_loss.backward()
        generator_optimizer.step()
        
        G_loss.append(generator_loss.data.item())
        if ((batch_idx + 1)% 500 == 0 and (epoch_idx + 1)%10 == 0):
            print("Training Steps Completed: ", batch_idx)
            
            with torch.no_grad():
                noise = torch.randn(batch_size,100).to(device)
                fake_labels = torch.randint(0, 10, (batch_size,)).to(device)
                generated_data = generator(noise, fake_labels).cpu().view(batch_size, 128, 128)
                for x in generated_data:
                    print(fake_labels[0].item())
                    plt.imshow(x.detach().numpy(), interpolation='nearest',cmap='gray')
                    plt.show()

                    break


    print('[%d/%d]: loss_d: %.3f, loss_g: %.3f' % (
            (epoch_idx), n_epochs, torch.mean(torch.FloatTensor(D_loss)), torch.mean(torch.FloatTensor(G_loss))))
# Out:
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-7d5e564f388e> in <module>
#      23         discriminator_optimizer.zero_grad()
#      24
# ---> 25         discriminator_output_for_true_data = discriminator(true_data, digit_labels).view(batch_size)
#      26         true_discriminator_loss = loss(discriminator_output_for_true_data, true_labels)
#      27
#
# /opt/anaconda3/envs/rnvp/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# <ipython-input-67-c513e3d4cd28> in forward(self, x, labels)
#      30
#      31     def forward(self, x, labels):
# ---> 32         c = self.label_embedding(labels)
#      33         x = torch.cat([x, c], 1)
#      34         output = self.hidden_layer1(x)
#
# /opt/anaconda3/envs/rnvp/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# /opt/anaconda3/envs/rnvp/lib/python3.7/site-packages/torch/nn/modules/sparse.py in forward(self, input)
#     108         return F.embedding(
#     109             input, self.weight, self.padding_idx, self.max_norm,
# --> 110             self.norm_type, self.scale_grad_by_freq, self.sparse)
#     111
#     112     def extra_repr(self):
#
# /opt/anaconda3/envs/rnvp/lib/python3.7/site-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1108         with torch.no_grad():
#    1109             torch.embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1110     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1111
#    1112
#
# TypeError: embedding(): argument 'indices' (position 2) must be Tensor, not int
